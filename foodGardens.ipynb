# %% [markdown]
# New research reveals that beaver dams are helping to clean pollution from streams and rivers. Dams slow the passage of water through a river and can act as a natural filter. Ponds—which grow from water backed up by the dam—can suspend sediment and pollutants, like nitrogen and phosphorous.

# %%
import pandas as pd
import numpy as np

# df = pd.read_csv('dams.csv')
# # xyz ngbhd has the most watersheds and the biggest ones
# df.plot(x = "dam_name", y=["drain_area"], kind="bar")
# # drain area is the amount of land where precipitation goes to
# # more land, more water area... kinda 
# area = df['drain_area'].max()
# maxAreaIndex = df['drain_area'].idxmax()

# biggest_basin = df.iloc[maxAreaIndex]
# print('From the bar chart, you can (kinda) see that the biggest dam is the ', biggest_basin['dam_name'], ' with a drainage area of ', area)

df = pd.read_csv('food_gardens.csv')
plot = df.groupby(['zip_code']).sum().plot(kind='pie', y = 'grower_id', figsize = (7, 7))
print(plot)
print("This piechart organizes all the food gardens based on zipcode. As you can see, the zipcode with the most foodgardens is 15206. Since they have the most gardens, it would be most benefiicla to live there")
# Out:
# AxesSubplot(0.135,0.125;0.755x0.755)
# This piechart organizes all the food gardens based on zipcode. As you can see, the zipcode with the most foodgardens is 15206. Since they have the most gardens, it would be most benefiicla to live there
